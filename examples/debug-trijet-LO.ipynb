# %%
import pandas as pd
import pypowhegparse as ppp
pd.set_option('display.max_columns', None)
folder = "/home/apn/git/POWHEG-BOX-V2/trijet/testrun-lhc/"

# %% [markdown]
# ## Checklimits

# %%
ppp.print_stats(folder)
ppp.print_warn_grep(folder,3)
# Out:
# #WARN    =  429379
# #WWARN   =  368963
# #WWWARN  =  227513
# #WWWWARN =  3555
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Counters

# %%
#ddf = ppp.load_counter_folder(folder)
#ddf.xs("pwgcounters-st4").describe()

# %%
#ppp.multi_describe(ddf)#[["real time (sec)"]]

# %% [markdown]
# ## Stat

# %%
ddf = ppp.load_stat_folder(folder)
#ddf.xs("pwg-0001-stat.dat").describe()

# %%
ppp.multi_describe(ddf)
# Out:
# proc                btilde pos.   weights:  btilde pos.   weights:+-stat  \
# pwg-stat     count                2.000000                      2.000000
#              mean                 6.087931                      3.150379
#              std                  0.055060                      0.814950
#              min                  6.048998                      2.574123
#              25%                  6.068464                      2.862251
#              50%                  6.087931                      3.150379
#              75%                  6.107398                      3.438507
#              max                  6.126864                      3.726635
# pwg-st2-stat count                2.000000                      2.000000
#              mean                 6.087931                      3.150379
#              std                  0.055060                      0.814950
#              min                  6.048998                      2.574123
#              25%                  6.068464                      2.862251
#              50%                  6.087931                      3.150379
#              75%                  6.107398                      3.438507
#              max                  6.126864                      3.726635
#
# proc                btilde |neg.| weights:  btilde |neg.| weights:+-stat  \
# pwg-stat     count                     2.0                           2.0
#              mean                      0.0                           0.0
#              std                       0.0                           0.0
#              min                       0.0                           0.0
#              25%                       0.0                           0.0
#              50%                       0.0                           0.0
#              75%                       0.0                           0.0
#              max                       0.0                           0.0
# pwg-st2-stat count                     2.0                           2.0
#              mean                      0.0                           0.0
#              std                       0.0                           0.0
#              min                       0.0                           0.0
#              25%                       0.0                           0.0
#              50%                       0.0                           0.0
#              75%                       0.0                           0.0
#              max                       0.0                           0.0
#
# proc                btilde Total (pos.-|neg.|):  \
# pwg-stat     count                     2.000000
#              mean                      6.087931
#              std                       0.055060
#              min                       6.048998
#              25%                       6.068464
#              50%                       6.087931
#              75%                       6.107398
#              max                       6.126864
# pwg-st2-stat count                     2.000000
#              mean                      6.087931
#              std                       0.055060
#              min                       6.048998
#              25%                       6.068464
#              50%                       6.087931
#              75%                       6.107398
#              max                       6.126864
#
# proc                btilde Total (pos.-|neg.|):+-stat  \
# pwg-stat     count                           2.000000
#              mean                            3.150379
#              std                             0.814950
#              min                             2.574123
#              25%                             2.862251
#              50%                             3.150379
#              75%                             3.438507
#              max                             3.726635
# pwg-st2-stat count                           2.000000
#              mean                            3.150379
#              std                             0.814950
#              min                             2.574123
#              25%                             2.862251
#              50%                             3.150379
#              75%                             3.438507
#              max                             3.726635
#
# proc                Remnant cross section in pb  \
# pwg-stat     count                          2.0
#              mean                           0.0
#              std                            0.0
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0
# pwg-st2-stat count                          2.0
#              mean                           0.0
#              std                            0.0
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0
#
# proc                Remnant cross section in pb+-stat  \
# pwg-stat     count                                2.0
#              mean                                 0.0
#              std                                  0.0
#              min                                  0.0
#              25%                                  0.0
#              50%                                  0.0
#              75%                                  0.0
#              max                                  0.0
# pwg-st2-stat count                                2.0
#              mean                                 0.0
#              std                                  0.0
#              min                                  0.0
#              25%                                  0.0
#              50%                                  0.0
#              75%                                  0.0
#              max                                  0.0
#
# proc                suppression factor in pb  suppression factor in pb+-stat  \
# pwg-stat     count                  2.000000                        2.000000
#              mean                   6.087931                        3.150379
#              std                    0.055060                        0.814950
#              min                    6.048998                        2.574123
#              25%                    6.068464                        2.862251
#              50%                    6.087931                        3.150379
#              75%                    6.107398                        3.438507
#              max                    6.126864                        3.726635
# pwg-st2-stat count                  2.000000                        2.000000
#              mean                   6.087931                        3.150379
#              std                    0.055060                        0.814950
#              min                    6.048998                        2.574123
#              25%                    6.068464                        2.862251
#              50%                    6.087931                        3.150379
#              75%                    6.107398                        3.438507
#              max                    6.126864                        3.726635
#
# proc                  negative weight fraction:
# pwg-stat     count                          2.0
#              mean                           0.0
#              std                            0.0
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0
# pwg-st2-stat count                          2.0
#              mean                           0.0
#              std                            0.0
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0

# %% [markdown]
# ## Top

# %%
dddf = ppp.load_top_folder(folder)
dddf
# Out:
# title                              pvalue       chi2  \
# pwg-btlgrid 1 dim=           1   0.000383  12.611733
#               dim=           2   0.000109  14.966477
#               dim=           3   0.000453  12.301483
#               dim=           4   0.002232   9.348181
#               dim=           5   0.005094   7.845819
#               dim=           6   0.000535  11.991049
#               dim=           7        0.0  42.188204
#               dim=           8   0.023958   5.097656
#               dim=           9   0.001629   9.927161
#               dim=          10   0.001523  10.050989
#             2 dim=           1   0.000383  12.611733
#               dim=           2   0.000109  14.966477
#               dim=           3   0.000453  12.301483
#               dim=           4   0.002232   9.348181
#               dim=           5   0.005094   7.845819
#               dim=           6   0.000535  11.991049
#               dim=           7        0.0  42.188204
#               dim=           8   0.023958   5.097656
#               dim=           9   0.001629   9.927161
#               dim=          10   0.001523  10.050989
# pwg-rmngrid 1 dim=           1   0.003426   8.565345
#               dim=           2    0.02951   4.737629
#               dim=           3   0.005063   7.856631
#               dim=           4   0.036916   4.354295
#               dim=           5   0.000001  23.306668
#               dim=           6   0.109678   2.558857
#               dim=           7   0.001738   9.807292
#               dim=           8        0.0  36.317344
#               dim=           9   0.018824   5.517782
#               dim=          10   0.015416   5.868325
#             2 dim=           1   0.003426   8.565345
#               dim=           2    0.02951   4.737629
#               dim=           3   0.005063   7.856631
#               dim=           4   0.036916   4.354295
#               dim=           5   0.000001  23.306668
#               dim=           6   0.109678   2.558857
#               dim=           7   0.001738   9.807292
#               dim=           8        0.0  36.317344
#               dim=           9   0.018824   5.517782
#               dim=          10   0.015416   5.868325
#
# title                                                                         plot
# pwg-btlgrid 1 dim=           1   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           2   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           3   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           4   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           5   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           6   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           7   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           8   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           9   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=          10   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#             2 dim=           1   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           2   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           3   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           4   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           5   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           6   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           7   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           8   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           9   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=          10   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
# pwg-rmngrid 1 dim=           1   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           2   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           3   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           4   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           5   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           6   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           7   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           8   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           9   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=          10   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#             2 dim=           1   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           2   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           3   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           4   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           5   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           6   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           7   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           8   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=           9   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...
#               dim=          10   <pytopdrawer.topplot.TopPlot object at 0x7fbd1...

# %%
for p in dddf.xs("pwg-btlgrid").xs(1)["plot"]:
    p.show(size=(5,5),fmt="-")
#for p in dddf.xs("pwg-rmngrid").xs(1)["plot"]:
#    p.show(size=(5,5),fmt="-")

# %%
import numpy as np
from uncertainties import unumpy as unp
def fitr(x):
    return 1./(unp.exp(-10*(x-0.5))+1)
for p in [dddf.xs("pwg-btlgrid").xs(1)["plot"][0]]:
    p.fit(fitr,size=(5,5),fmt="-",logx=False,fselector=lambda x,y : np.logical_and(x>0,x>0) ,extrapolate=False)

# %%
for p in [dddf.xs("pwg-btlgrid").xs(1)["plot"][0]]:
    p.auto(size=(10,10),fmt="-",logx=True,fselector=lambda x,y : x>0,extrapolate=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:03<00:00,  8.23it/s]

# %% [markdown]
# #
